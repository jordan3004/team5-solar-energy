# %% [markdown]
# ##Team 5 Jupyter notebook - Project 1

# %%
#Dependencies
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
import pandas as pd
import numpy as np
import requests
import random
import gmaps
import json
import os

# %%
## Create a url API INEGI
url_path = https://www.inegi.org.mx/app/api/indicadores/desarrolladores/jsonxml/INDICATOR/668921,6207061405/es//true/BIE/2.0/1eda5bfc-0e53-ec67-9976-42321b74e950?type=json

# %%
#Import documentation
df = pd.read_excel("Resources/Centraleselectricas-2.xlsx")
df
# Out:
#            No.  \
# 0            1
# 1            2
# 2            3
# 3            4
# 4            5
# ...        ...
# 100332  100333
# 100333  100334
# 100334  100335
# 100335  100336
# 100336  100337
#
#         Número de identificación del proyecto asignado por el distribuidor  \
# 0                                                   62003
# 1                                                   64518
# 2                                                   63639
# 3                                                   63640
# 4                                                   66728
# ...                                                   ...
# 100332                                             196291
# 100333                                             195138
# 100334                                             213873
# 100335                                             202369
# 100336                                             202340
#
#        Nivel de tensión en el punto de interconexión  Número de fases  \
# 0                                               BAJA                2
# 1                                               BAJA                2
# 2                                               BAJA                2
# 3                                               BAJA                2
# 4                                               BAJA                2
# ...                                              ...              ...
# 100332                                          BAJA                2
# 100333                                          BAJA                2
# 100334                                          BAJA                2
# 100335                                          BAJA                2
# 100336                                          BAJA                3
#
#         Capacidad de la central eléctrica (kW)  \
# 0                                         1.65
# 1                                         4.88
# 2                                         3.72
# 3                                         5.58
# 4                                         3.72
# ...                                        ...
# 100332                                    1.50
# 100333                                    2.64
# 100334                                    1.00
# 100335                                    9.00
# 100336                                    1.00
#
#           Área Administrativa del Distribuidor (Division)  \
# 0                                DIVISION BAJA CALIFORNIA
# 1                                DIVISION BAJA CALIFORNIA
# 2                                DIVISION BAJA CALIFORNIA
# 3                                DIVISION BAJA CALIFORNIA
# 4                                DIVISION BAJA CALIFORNIA
# ...                                                   ...
# 100332  DIVISION VALLE MEXICO SUR                     ...
# 100333  DIVISION VALLE MEXICO SUR                     ...
# 100334  DIVISION VALLE MEXICO SUR                     ...
# 100335  DIVISION VALLE MEXICO SUR                     ...
# 100336  DIVISION VALLE MEXICO SUR                     ...
#
#        Área Administrativa del Distribuidor (Zona)  \
# 0                                     ZONA TIJUANA
# 1                                     ZONA TIJUANA
# 2                                     ZONA TIJUANA
# 3                                     ZONA TIJUANA
# 4                                     ZONA TIJUANA
# ...                                            ...
# 100332    ZONA VOLCANES
# 100333    ZONA VOLCANES
# 100334    ZONA VOLCANES
# 100335    ZONA VOLCANES
# 100336    ZONA ZOCALO
#
#                                           Estado  \
# 0                                Baja California
# 1                                Baja California
# 2                                Baja California
# 3                                Baja California
# 4                                Baja California
# ...                                          ...
# 100332  Estado de México
# 100333  Estado de México
# 100334  Estado de México
# 100335  Estado de México
# 100336  Estado de México
#
#                                        Municipio Fecha Solicitud  \
# 0                                        Tijuana      2017-05-29
# 1                                        Tijuana      2017-04-13
# 2                                        Tijuana      2017-05-02
# 3                                        Tijuana      2017-04-20
# 4                                        Tijuana      2017-04-21
# ...                                          ...             ...
# 100332  Amanalco                                      2019-11-26
# 100333  Calimaya                                      2019-08-29
# 100334  Tenango del Aire                              2019-12-20
# 100335  Tlalmanalco                                   2019-07-23
# 100336  Metepec                                       2019-09-19
#
#        Estado en que se encuentra la solicitud: Recibida/Atendida/En lista de espera/Cancelada  \
# 0                                                ATENDIDA
# 1                                                ATENDIDA
# 2                                                ATENDIDA
# 3                                                ATENDIDA
# 4                                                ATENDIDA
# ...                                                   ...
# 100332                                 EN LISTA DE ESPERA
# 100333                                 EN LISTA DE ESPERA
# 100334                                 EN LISTA DE ESPERA
# 100335                                 EN LISTA DE ESPERA
# 100336                                 ATENDIDA
#
#        Fecha de Interconexión Física  \
# 0                         2017-05-31
# 1                         2017-04-19
# 2                         2017-05-11
# 3                         2017-04-24
# 4                         2017-04-25
# ...                              ...
# 100332                    2019-12-03
# 100333                    2019-09-05
# 100334                    2019-12-27
# 100335                    2019-07-30
# 100336                    2019-09-26
#
#        Estudio de interconexión requerido (Si/No)  \
# 0                                              No
# 1                                              No
# 2                                              No
# 3                                              No
# 4                                              No
# ...                                           ...
# 100332                                         NO
# 100333                                         NO
# 100334                                         NO
# 100335                                         NO
# 100336                                         NO
#
#                                                Tecnología  \
# 0                                 FUENTE DE ENERGIA SOLAR
# 1                                 FUENTE DE ENERGIA SOLAR
# 2                                 FUENTE DE ENERGIA SOLAR
# 3                                 FUENTE DE ENERGIA SOLAR
# 4                                 FUENTE DE ENERGIA SOLAR
# ...                                                   ...
# 100332  FUENTE DE ENERGIA SOLAR                       ...
# 100333  FUENTE DE ENERGIA SOLAR                       ...
# 100334  FUENTE DE ENERGIA SOLAR                       ...
# 100335  FUENTE DE ENERGIA SOLAR                       ...
# 100336  FUENTE DE ENERGIA SOLAR                       ...
#
#           Ubicación por circuito de distribución  \
# 0                                       RII04175
# 1                                       HMO04155
# 2                                       HMO04155
# 3                                       HMO04155
# 4                                       HMO04155
# ...                                          ...
# 100332  IXL53085
# 100333  JCP53035
# 100334  JCP53025
# 100335  AGV53015
# 100336  CDS53080
#
#        Capacidad del circuito de distribución para albergar CE de GD  \
# 0                                           No disponible
# 1                                           No disponible
# 2                                           No disponible
# 3                                           No disponible
# 4                                           No disponible
# ...                                                   ...
# 100332                                               2.62
# 100333                                               1.82
# 100334                                               2.02
# 100335                                               3.31
# 100336                                               2.83
#
#                        Ubicación por subestación  \
# 0                                            RIO
# 1                                      HIPODROMO
# 2                                      HIPODROMO
# 3                                      HIPODROMO
# 4                                      HIPODROMO
# ...                                          ...
# 100332  IXTAPALUCA
# 100333  JUCHITEPEC
# 100334  JUCHITEPEC
# 100335  AGUA VIVA
# 100336  CONDESA
#
#        Ubicación por Red de Distribución   Ubicación por NodoP  \
# 0                          No disponible              07RII-69
# 1                          No disponible              07HMO-69
# 2                          No disponible              07HMO-69
# 3                          No disponible              07HMO-69
# 4                          No disponible              07HMO-69
# ...                                  ...                   ...
# 100332                     No Disponible  01IXL-230
# 100333                     No Disponible  01JCP-85
# 100334                     No Disponible  01JCP-85
# 100335                     No Disponible  01AGV-85
# 100336                     No Disponible  01CDS-85
#
#                  Regímen de contraprestación seleccionado
# 0                                MEDICIÓN NETA DE ENERGÍA
# 1                                MEDICIÓN NETA DE ENERGÍA
# 2                                MEDICIÓN NETA DE ENERGÍA
# 3                                MEDICIÓN NETA DE ENERGÍA
# 4                                MEDICIÓN NETA DE ENERGÍA
# ...                                                   ...
# 100332  MEDICIÓN NETA DE ENERGÍA                      ...
# 100333  MEDICIÓN NETA DE ENERGÍA                      ...
# 100334  MEDICIÓN NETA DE ENERGÍA                      ...
# 100335  MEDICIÓN NETA DE ENERGÍA                      ...
# 100336  MEDICIÓN NETA DE ENERGÍA                      ...
#
# [100337 rows x 20 columns]

# %%
#Clean Data
col=['No.','Número de identificación del proyecto asignado por el distribuidor','Nivel de tensión en el punto de interconexión'
, 'Número de fases','Área Administrativa del Distribuidor (Division)','Área Administrativa del Distribuidor (Zona)', 'Ubicación por circuito de distribución','Capacidad del circuito de distribución para albergar CE de GD',
    'Ubicación por subestación','Ubicación por Red de Distribución','Ubicación por NodoP','Regímen de contraprestación seleccionado','Estudio de interconexión requerido (Si/No)'
    ]
clean_df= df.drop(columns=col)
clean_df['year']=pd.DatetimeIndex(clean_df['Fecha de Interconexión Física']).year
clean_df_loc = clean_df.loc[clean_df["Estado en que se encuentra la solicitud: Recibida/Atendida/En lista de espera/Cancelada"] == "ATENDIDA"]
clean_df_loc = clean_df_loc.drop(columns = ["Estado en que se encuentra la solicitud: Recibida/Atendida/En lista de espera/Cancelada", "Fecha Solicitud", "Fecha de Interconexión Física", "Municipio"])
clean_df_gp = clean_df_loc.groupby(["year", "Estado", "Tecnología"]).sum()
clean_df_gp
# Out:
#                                                            Capacidad de la central eléctrica (kW)
# year Estado              Tecnología
# 2017 Aguascalientes      FUENTE DE ENERGIA SOLAR                                          5322.08
#      Baja California     FUENTE DE ENERGIA SOLAR                                          5689.40
#      Baja California Sur FUENTE DE ENERGIA SOLAR                                          2853.31
#      Campeche            FUENTE DE ENERGIA SOLAR                                           998.20
#      Chiapas             FUENTE DE ENERGIA SOLAR                                          1644.83
# ...                                                                                           ...
# 2019 Veracruz            FUENTE DE ENERGIA HIDROELECTRICA                                    8.20
#                          FUENTE DE ENERGIA SOLAR                                           851.55
#      Yucatán             FUENTE DE ENERGIA GAS                                               1.06
#                          FUENTE DE ENERGIA SOLAR                                          7376.56
#      Zacatecas           FUENTE DE ENERGIA SOLAR                                           265.05
#
# [138 rows x 1 columns]

# %%
clean_df_gp.reset_index(inplace = True)
clean_df_gp["Capacidad_kW_2017"] = clean_df_gp.loc[clean_df_gp.year == 2017,"Capacidad de la central eléctrica (kW)"]
clean_df_gp["Capacidad_kW_2018"] = clean_df_gp.loc[clean_df_gp.year == 2018,"Capacidad de la central eléctrica (kW)"]
clean_df_gp["Capacidad_kW_2019"] = clean_df_gp.loc[clean_df_gp.year == 2019,"Capacidad de la central eléctrica (kW)"]
clean_df_gp
# Out:
#      year               Estado                        Tecnología  \
# 0    2017       Aguascalientes           FUENTE DE ENERGIA SOLAR
# 1    2017      Baja California           FUENTE DE ENERGIA SOLAR
# 2    2017  Baja California Sur           FUENTE DE ENERGIA SOLAR
# 3    2017             Campeche           FUENTE DE ENERGIA SOLAR
# 4    2017              Chiapas           FUENTE DE ENERGIA SOLAR
# ..    ...                  ...                               ...
# 133  2019            Veracruz   FUENTE DE ENERGIA HIDROELECTRICA
# 134  2019            Veracruz            FUENTE DE ENERGIA SOLAR
# 135  2019              Yucatán             FUENTE DE ENERGIA GAS
# 136  2019              Yucatán           FUENTE DE ENERGIA SOLAR
# 137  2019            Zacatecas           FUENTE DE ENERGIA SOLAR
#
#      Capacidad de la central eléctrica (kW)  Capacidad_kW_2017  \
# 0                                   5322.08            5322.08
# 1                                   5689.40            5689.40
# 2                                   2853.31            2853.31
# 3                                    998.20             998.20
# 4                                   1644.83            1644.83
# ..                                      ...                ...
# 133                                    8.20                NaN
# 134                                  851.55                NaN
# 135                                    1.06                NaN
# 136                                 7376.56                NaN
# 137                                  265.05                NaN
#
#      Capacidad_kW_2018  Capacidad_kW_2019
# 0                  NaN                NaN
# 1                  NaN                NaN
# 2                  NaN                NaN
# 3                  NaN                NaN
# 4                  NaN                NaN
# ..                 ...                ...
# 133                NaN               8.20
# 134                NaN             851.55
# 135                NaN               1.06
# 136                NaN            7376.56
# 137                NaN             265.05
#
# [138 rows x 7 columns]

# %%
clean_df_gp.loc[clean_df_gp['Capacidad_kW_2017'].isnull(), 'Capacidad_kW_2017'] = 0
clean_df_gp.loc[clean_df_gp['Capacidad_kW_2018'].isnull(), 'Capacidad_kW_2018'] = 0
clean_df_gp.loc[clean_df_gp['Capacidad_kW_2019'].isnull(), 'Capacidad_kW_2019'] = 0
# columns=['level_0','year','Capacidad de la central eléctrica (kW)']
# clean_df_gp= df.drop(columns=col)
clean_df_gp
# Out:
#      year               Estado                        Tecnología  \
# 0    2017       Aguascalientes           FUENTE DE ENERGIA SOLAR
# 1    2017      Baja California           FUENTE DE ENERGIA SOLAR
# 2    2017  Baja California Sur           FUENTE DE ENERGIA SOLAR
# 3    2017             Campeche           FUENTE DE ENERGIA SOLAR
# 4    2017              Chiapas           FUENTE DE ENERGIA SOLAR
# ..    ...                  ...                               ...
# 133  2019            Veracruz   FUENTE DE ENERGIA HIDROELECTRICA
# 134  2019            Veracruz            FUENTE DE ENERGIA SOLAR
# 135  2019              Yucatán             FUENTE DE ENERGIA GAS
# 136  2019              Yucatán           FUENTE DE ENERGIA SOLAR
# 137  2019            Zacatecas           FUENTE DE ENERGIA SOLAR
#
#      Capacidad de la central eléctrica (kW)  Capacidad_kW_2017  \
# 0                                   5322.08            5322.08
# 1                                   5689.40            5689.40
# 2                                   2853.31            2853.31
# 3                                    998.20             998.20
# 4                                   1644.83            1644.83
# ..                                      ...                ...
# 133                                    8.20               0.00
# 134                                  851.55               0.00
# 135                                    1.06               0.00
# 136                                 7376.56               0.00
# 137                                  265.05               0.00
#
#      Capacidad_kW_2018  Capacidad_kW_2019
# 0                  0.0               0.00
# 1                  0.0               0.00
# 2                  0.0               0.00
# 3                  0.0               0.00
# 4                  0.0               0.00
# ..                 ...                ...
# 133                0.0               8.20
# 134                0.0             851.55
# 135                0.0               1.06
# 136                0.0            7376.56
# 137                0.0             265.05
#
# [138 rows x 7 columns]

# %%
#Data cleaning
b = pd.read_excel("Resources/4_itaee_var_anual_retro2.xlsx")
b
clean_state = b[["Estado","Crecimiento ITAEE 2017", "Crecimiento ITAEE 2018", "Crecimiento ITAEE 2019"]]
clean_state
# Out:
#                              Estado  Crecimiento ITAEE 2017  \
# 0                    Aguascalientes                2.459206
# 1                   Baja California                3.358687
# 2               Baja California Sur               10.708411
# 3                          Campeche              -10.446591
# 4              Coahuila de Zaragoza                5.444967
# 5                            Colima                3.485108
# 6                           Chiapas               -3.327992
# 7                         Chihuahua                3.307919
# 8                  Ciudad de México                3.001314
# 9                           Durango               -0.269926
# 10                       Guanajuato                4.648446
# 11                         Guerrero                0.222942
# 12                          Hidalgo                0.731799
# 13                          Jalisco                2.637927
# 14                           México                4.767403
# 15              Michoacán de Ocampo                3.180458
# 16                          Morelos                4.680166
# 17                          Nayarit                1.320559
# 18                       Nuevo León                3.876801
# 19                           Oaxaca               -2.348237
# 20                           Puebla                6.257958
# 21                       Querétaro                 4.588507
# 22                     Quintana Roo                4.174029
# 23                  San Luis Potosí                3.714593
# 24                          Sinaloa                1.269721
# 25                           Sonora               -0.471577
# 26                          Tabasco               -4.421999
# 27                       Tamaulipas               -0.165561
# 28                         Tlaxcala               -1.105406
# 29  Veracruz de Ignacio de la Llave               -1.136345
# 30                          Yucatán                4.189041
# 31                        Zacatecas               -0.094313
#
#     Crecimiento ITAEE 2018  Crecimiento ITAEE 2019
# 0                 3.727672               -0.031717
# 1                 2.284226                2.052373
# 2                16.815057               -7.103514
# 3                -1.422752               -2.153711
# 4                 1.233570                0.171539
# 5                 2.503819                4.320531
# 6                -2.138943               -2.460577
# 7                 1.956625                2.079865
# 8                 2.690299               -0.309418
# 9                 1.451128                0.600691
# 10                1.217743               -0.509247
# 11                2.938579               -1.394436
# 12                2.694535               -1.404298
# 13                2.607120                0.486627
# 14                3.325637               -2.159198
# 15                2.353999               -0.172473
# 16               -0.830630               -2.031776
# 17               -0.396213               -0.437479
# 18                3.584551                1.506020
# 19                3.964970               -3.218306
# 20                2.736075               -0.998883
# 21                2.909588                0.381487
# 22                5.077844               -0.159262
# 23                4.391795               -0.862672
# 24                2.437391                0.959803
# 25                0.947335               -0.561359
# 26               -8.049352               -5.282788
# 27                1.851065                1.707301
# 28                3.623591                6.256509
# 29                2.383219                0.693376
# 30                3.157871                1.416235
# 31               -0.585084               -3.304483

# %%
clean_state.rename(columns = {"Crecimiento ITAEE 2017":"Crecimiento_2017"
                              ,"Crecimiento ITAEE 2018":"Crecimiento_2018"
                               ,"Crecimiento ITAEE 2019":"Crecimiento_2019"},inplace= True)
clean_state
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py:4125: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(
#                              Estado  Crecimiento_2017  Crecimiento_2018  \
# 0                    Aguascalientes          2.459206          3.727672
# 1                   Baja California          3.358687          2.284226
# 2               Baja California Sur         10.708411         16.815057
# 3                          Campeche        -10.446591         -1.422752
# 4              Coahuila de Zaragoza          5.444967          1.233570
# 5                            Colima          3.485108          2.503819
# 6                           Chiapas         -3.327992         -2.138943
# 7                         Chihuahua          3.307919          1.956625
# 8                  Ciudad de México          3.001314          2.690299
# 9                           Durango         -0.269926          1.451128
# 10                       Guanajuato          4.648446          1.217743
# 11                         Guerrero          0.222942          2.938579
# 12                          Hidalgo          0.731799          2.694535
# 13                          Jalisco          2.637927          2.607120
# 14                           México          4.767403          3.325637
# 15              Michoacán de Ocampo          3.180458          2.353999
# 16                          Morelos          4.680166         -0.830630
# 17                          Nayarit          1.320559         -0.396213
# 18                       Nuevo León          3.876801          3.584551
# 19                           Oaxaca         -2.348237          3.964970
# 20                           Puebla          6.257958          2.736075
# 21                       Querétaro           4.588507          2.909588
# 22                     Quintana Roo          4.174029          5.077844
# 23                  San Luis Potosí          3.714593          4.391795
# 24                          Sinaloa          1.269721          2.437391
# 25                           Sonora         -0.471577          0.947335
# 26                          Tabasco         -4.421999         -8.049352
# 27                       Tamaulipas         -0.165561          1.851065
# 28                         Tlaxcala         -1.105406          3.623591
# 29  Veracruz de Ignacio de la Llave         -1.136345          2.383219
# 30                          Yucatán          4.189041          3.157871
# 31                        Zacatecas         -0.094313         -0.585084
#
#     Crecimiento_2019
# 0          -0.031717
# 1           2.052373
# 2          -7.103514
# 3          -2.153711
# 4           0.171539
# 5           4.320531
# 6          -2.460577
# 7           2.079865
# 8          -0.309418
# 9           0.600691
# 10         -0.509247
# 11         -1.394436
# 12         -1.404298
# 13          0.486627
# 14         -2.159198
# 15         -0.172473
# 16         -2.031776
# 17         -0.437479
# 18          1.506020
# 19         -3.218306
# 20         -0.998883
# 21          0.381487
# 22         -0.159262
# 23         -0.862672
# 24          0.959803
# 25         -0.561359
# 26         -5.282788
# 27          1.707301
# 28          6.256509
# 29          0.693376
# 30          1.416235
# 31         -3.304483

# %%
#Merge Data
merge_df = pd.merge(clean_df_gp, clean_state, how = "inner", on = "Estado")
merge_df
# Out:
#      year          Estado                Tecnología  \
# 0    2017  Aguascalientes   FUENTE DE ENERGIA SOLAR
# 1    2018  Aguascalientes   FUENTE DE ENERGIA SOLAR
# 2    2019  Aguascalientes  FUENTE DE ENERGIA BIOGAS
# 3    2019  Aguascalientes     FUENTE DE ENERGIA GAS
# 4    2019  Aguascalientes   FUENTE DE ENERGIA SOLAR
# ..    ...             ...                       ...
# 109  2019         Yucatán     FUENTE DE ENERGIA GAS
# 110  2019         Yucatán   FUENTE DE ENERGIA SOLAR
# 111  2017       Zacatecas   FUENTE DE ENERGIA SOLAR
# 112  2018       Zacatecas   FUENTE DE ENERGIA SOLAR
# 113  2019       Zacatecas   FUENTE DE ENERGIA SOLAR
#
#      Capacidad de la central eléctrica (kW)  Capacidad_kW_2017  \
# 0                                   5322.08            5322.08
# 1                                   3963.01               0.00
# 2                                    196.01               0.00
# 3                                      4.10               0.00
# 4                                   3034.03               0.00
# ..                                      ...                ...
# 109                                    1.06               0.00
# 110                                 7376.56               0.00
# 111                                 1321.23            1321.23
# 112                                  821.40               0.00
# 113                                  265.05               0.00
#
#      Capacidad_kW_2018  Capacidad_kW_2019  Crecimiento_2017  Crecimiento_2018  \
# 0                 0.00               0.00          2.459206          3.727672
# 1              3963.01               0.00          2.459206          3.727672
# 2                 0.00             196.01          2.459206          3.727672
# 3                 0.00               4.10          2.459206          3.727672
# 4                 0.00            3034.03          2.459206          3.727672
# ..                 ...                ...               ...               ...
# 109               0.00               1.06          4.189041          3.157871
# 110               0.00            7376.56          4.189041          3.157871
# 111               0.00               0.00         -0.094313         -0.585084
# 112             821.40               0.00         -0.094313         -0.585084
# 113               0.00             265.05         -0.094313         -0.585084
#
#      Crecimiento_2019
# 0           -0.031717
# 1           -0.031717
# 2           -0.031717
# 3           -0.031717
# 4           -0.031717
# ..                ...
# 109          1.416235
# 110          1.416235
# 111         -3.304483
# 112         -3.304483
# 113         -3.304483
#
# [114 rows x 10 columns]

# %%
#API's

# %%
#Ploatings
