# %% [markdown]
# ##Team 5 Jupyter notebook - Project 1

# %%
#Dependencies
import pandas as pd

# %%
## Create a url API INEGI
url_path = https://www.inegi.org.mx/app/api/indicadores/desarrolladores/jsonxml/INDICATOR/668921,6207061405/es//true/BIE/2.0/1eda5bfc-0e53-ec67-9976-42321b74e950?type=json
# Out:
#   File "<ipython-input-11-e4fe2fad7f6a>", line 2
#     url_path = https://www.inegi.org.mx/app/api/indicadores/desarrolladores/jsonxml/INDICATOR/668921,6207061405/es//true/BIE/2.0/
#                     ^
# SyntaxError: invalid syntax

# %%
#Data cleaning

# %%
#API's

# %%
#Ploatings
